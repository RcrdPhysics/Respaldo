# %%
import pandas as pd
import numpy as np
# use .dot format to visualize a tree
from ipywidgets import Image
from io import StringIO
import pydotplus #pip install pydotplus
from sklearn.tree import export_graphviz

# %%
EOS_FAM = pd.read_csv('EOS.csv', delimiter=';')
EOS_FAM
# Out:
#        NUMBER        NAME       DESIG  FAM  S  CLASS S.1   F     DIA S.2 ...   \
# 0       221.0         Eos         NaN  EOS  S      K   S NaN  103.87   M ...
# 1       320.0   Katharina         NaN  EOS  A      S   C NaN   24.57   M ...
# 2       339.0    Dorothea      1892 G  EOS  S      K   S NaN   38.25   M ...
# 3       450.0    Brigitta     1899 EV  EOS  T    CSU   D NaN   33.46   M ...
# 4       513.0   Centesima     1903 LY  EOS  S      K   S NaN   50.15   M ...
# 5       520.0   Franziska     1903 MV  EOS  T    CGU   D NaN   28.61   L ...
# 6       529.0    Preziosa     1904 NT  EOS  T      S   D NaN   31.84   L ...
# 7       562.0      Salome     1905 QH  EOS  T      S   D NaN   30.56   L ...
# 8       573.0       Recha     1905 RC  EOS  A      S   D NaN   48.21   M ...
# 9       579.0     Sidonia     1905 SD  EOS  S      K   D NaN   85.95   L ...
# 10      590.0     Tomyris     1906 TO  EOS  A      S   D NaN   39.78   L ...
# 11      608.0    Adolfine     1906 VD  EOS  A      S   D NaN   25.39   M ...
# 12      633.0      Zelima     1907 ZM  EOS  S      S   S NaN   34.37   M ...
# 13      639.0      Latona     1907 ZT  EOS  T      S   D NaN   70.80   L ...
# 14      651.0   Antikleia     1907 AN  EOS  T      S   S NaN   33.04   M ...
# 15      653.0    Berenike     1907 BK  EOS  S      K   D NaN   39.18   L ...
# 16      661.0     Cloelia     1908 CL  EOS  S      K   D NaN   48.08   M ...
# 17      669.0      Kypria     1908 DQ  EOS  T      S   S NaN   31.75   M ...
# 18      742.0     Edisona     1913 QU  EOS  S      K   S NaN   45.60   M ...
# 19      766.0    Moguntia     1913 SW  EOS  T     MU   D NaN   31.18   L ...
# 20      775.0     Lumiere     1914 TX  EOS  T      S   D NaN   33.54   L ...
# 21      798.0        Ruth     1914 VT  EOS  T      M   D NaN   43.01   M ...
# 22      807.0    Ceraskia     1915 WY  EOS  T      S   D NaN   26.15   L ...
# 23      833.0      Monica     1916 AC  EOS  A      S   C NaN   21.40   M ...
# 24      890.0    Waltraut     1918 DK  EOS  T  CTGU:   S NaN   27.33   M ...
# 25      992.0      Swasey     1922 ND  EOS  A      S   D NaN   27.52   M ...
# 26     1033.0      Simona     1924 SM  EOS  A      S   D NaN   24.71   M ...
# 27     1075.0      Helina     1926 SC  EOS  T     SU   S NaN   35.52   S ...
# 28     1087.0      Arabis     1927 RD  EOS  T      S   D NaN   31.67   L ...
# 29     1095.0      Tulipa     1926 GS  EOS  A      S   D NaN   31.53   L ...
# ..        ...         ...         ...  ... ..    ...  ..  ..     ...  .. ...
# 444  167631.0   2004 CE87   2004 CE87  EOS  A      S   C NaN    3.39   M ...
# 445  177075.0   2003 FR36   2003 FR36  EOS  A      S   D NaN    2.29   T ...
# 446  178014.0     2006 RG     2006 RG  EOS  A      S   C NaN    2.90   T ...
# 447  184616.0   2005 RE11   2005 RE11  EOS  A      S   C NaN    2.88   T ...
# 448  195704.0   2002 PH35   2002 PH35  EOS  A      S   C NaN    2.50   T ...
# 449  196806.0  2003 SQ218  2003 SQ218  EOS  A      S   C NaN    2.66   T ...
# 450  201297.0   2002 SK60   2002 SK60  EOS  A      S   C NaN    2.21   T ...
# 451  201369.0  2002 TA278  2002 TA278  EOS  A      S   C NaN    3.72   M ...
# 452  202321.0   2005 EG55   2005 EG55  EOS  A      S   C NaN    2.01   T ...
# 453  213779.0   2003 EP14   2003 EP14  EOS  A      C   C NaN    2.95   M ...
# 454  224958.0   2007 EM18   2007 EM18  EOS  A      S   C NaN    2.24   M ...
# 455  226971.0  2004 VH112  2004 VH112  EOS  A      S   C NaN    2.30   T ...
# 456  237286.0   2008 XB21   2008 XB21  EOS  A      S   C NaN    3.09   M ...
# 457  249738.0  2000 SB159  2000 SB159  EOS  A      S   D NaN    2.21   T ...
# 458  255093.0   2005 UW48   2005 UW48  EOS  A      S   C NaN    2.15   T ...
# 459  274707.0  2008 UG100  2008 UG100  EOS  A      S   C NaN    2.09   T ...
# 460  286096.0   2001 TR47   2001 TR47  EOS  A      S   C NaN    2.08   T ...
# 461  287471.0   2003 AK46   2003 AK46  EOS  A      S   C NaN    2.53   T ...
# 462  288286.0   2004 AT12   2004 AT12  EOS  A      S   C NaN    2.69   M ...
# 463  324798.0   2007 HO20   2007 HO20  EOS  A      S   C NaN    2.03   T ...
# 464  346759.0   2009 BV46   2009 BV46  EOS  A      S   C NaN    1.82   T ...
# 465  353778.0   2012 HA77   2012 HA77  EOS  A      S   C NaN    2.40   T ...
# 466  357911.0  2005 VR131  2005 VR131  EOS  A      S   C NaN    2.24   M ...
# 467  362493.0   2010 TM25   2010 TM25  EOS  A      S   C NaN    2.17   T ...
# 468  370227.0   2002 OC27   2002 OC27  EOS  A      S   C NaN    2.06   T ...
# 469  385893.0  2006 SJ232  2006 SJ232  EOS  A      S   C NaN    2.05   T ...
# 470  397062.0  2005 UX149  2005 UX149  EOS  A      S   C NaN    1.78   T ...
# 471  425326.0   2010 AS55   2010 AS55  EOS  A      S   C NaN    1.56   T ...
# 472  428958.0   2008 YM91   2008 YM91  EOS  A      S   C NaN    2.24   M ...
# 473       NaN   2011 WJ33   2011 WJ33  EOS  A      S   M NaN    2.82   M ...
#
#      F.3  AMIN  AMAX    U  NOTES BIN  PRI  SAM   SD   WF
# 0    NaN  0.05  0.12  3.0    NaN NaN  NaN    Y  NaN  NaN
# 1    NaN  0.19  0.21  3.0    NaN NaN  NaN  NaN  NaN  NaN
# 2    NaN  0.06  0.10  3.0    NaN NaN  NaN  NaN  NaN  NaN
# 3    NaN  0.22  0.31  3.0    NaN NaN  NaN    Y  NaN  NaN
# 452  NaN   NaN  0.59  2.0    NaN NaN  NaN  NaN  NaN    Y
# 453  NaN   NaN  0.96  2.0    NaN NaN  NaN  NaN  NaN    Y
# 454  NaN   NaN   NaN  NaN     HN NaN  NaN  NaN  NaN    Y
# 455  NaN   NaN  0.76  2.0    NaN NaN  NaN  NaN  NaN    Y
# 456  NaN   NaN   NaN  NaN     HN NaN  NaN  NaN  NaN    Y
# 457  NaN   NaN  0.11  1.0      + NaN  NaN  NaN  NaN  NaN
# 458  NaN   NaN  0.41  2.0    NaN NaN  NaN  NaN  NaN    Y
# 459  NaN   NaN  0.76  2.0    NaN NaN  NaN  NaN  NaN    Y
# 460  NaN   NaN  0.62  2.0    NaN NaN  NaN  NaN  NaN    Y
# 461  NaN   NaN  0.33  2.0    NaN NaN  NaN  NaN  NaN    Y
# 462  NaN   NaN   NaN  NaN     HN NaN  NaN  NaN  NaN    Y
# 463  NaN   NaN  1.31  2.0      - NaN  NaN  NaN  NaN    Y
# 464  NaN   NaN  0.80  2.0    NaN NaN  NaN  NaN  NaN    Y
# 465  NaN   NaN  0.64  2.0      + NaN  NaN  NaN  NaN    Y
# 466  NaN   NaN  0.36  1.0    NaN NaN  NaN  NaN  NaN  NaN
# 467  NaN   NaN  0.73  2.0    NaN NaN  NaN  NaN  NaN    Y
# 468  NaN   NaN  0.57  2.0    NaN NaN  NaN  NaN  NaN    Y
# 469  NaN   NaN  0.54  2.0    NaN NaN  NaN  NaN  NaN    Y
# 470  NaN   NaN  0.54  2.0    NaN NaN  NaN  NaN  NaN    Y
# 471  NaN   NaN  0.83  3.0      - NaN  NaN  NaN  NaN    Y
# 472  NaN   NaN   NaN  NaN     HN NaN  NaN  NaN  NaN    Y
# 473    >   NaN  0.16  NaN    NaN NaN  NaN  NaN    Y  NaN
#
# [474 rows x 29 columns]

# %%
EOS_FAM.sort_values('DIA').head()
# Out:
#        NUMBER        NAME       DESIG  FAM  S CLASS S.1   F   DIA S.2 ...  \
# 471  425326.0   2010 AS55   2010 AS55  EOS  A     S   C NaN  1.56   T ...
# 470  397062.0  2005 UX149  2005 UX149  EOS  A     S   C NaN  1.78   T ...
# 464  346759.0   2009 BV46   2009 BV46  EOS  A     S   C NaN  1.82   T ...
# 452  202321.0   2005 EG55   2005 EG55  EOS  A     S   C NaN  2.01   T ...
# 463  324798.0   2007 HO20   2007 HO20  EOS  A     S   C NaN  2.03   T ...
#
#      F.3  AMIN  AMAX    U  NOTES BIN  PRI  SAM   SD WF
# 471  NaN   NaN  0.83  3.0      - NaN  NaN  NaN  NaN  Y
# 470  NaN   NaN  0.54  2.0    NaN NaN  NaN  NaN  NaN  Y
# 464  NaN   NaN  0.80  2.0    NaN NaN  NaN  NaN  NaN  Y
# 452  NaN   NaN  0.59  2.0    NaN NaN  NaN  NaN  NaN  Y
# 463  NaN   NaN  1.31  2.0      - NaN  NaN  NaN  NaN  Y
#
# [5 rows x 29 columns]

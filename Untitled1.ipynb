# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('EOSMIND.csv', delimiter=';')
#df.replace([np.inf, -np.inf], np.nan)
df.dropna(subset=['DIA', 'AMIN'])
#df['AMIN'].dropna()
#df['DIA'].dropna()
# Out:
#         DIA  AMIN
# 0    103.87  0.05
# 1     24.57  0.19
# 2     38.25  0.06
# 3     33.46  0.22
# 4     50.15  0.18
# 5     28.61  0.35
# 7     30.56  0.17
# 8     48.21  0.20
# 9     85.95  0.02
# 10    39.78  0.21
# 11    25.39  0.16
# 12    34.37  0.14
# 13    70.80  0.07
# 14    33.04  0.13
# 15    39.18  0.03
# 17    31.75  0.17
# 18    45.60  0.24
# 19    31.18  0.06
# 20    33.54  0.19
# 21    43.01  0.19
# 22    26.15  0.25
# 23    21.40  0.11
# 24    27.33  0.30
# 27    35.52  0.64
# 28    31.67  0.14
# 29    31.53  0.14
# 31    35.76  0.20
# 32    34.80  0.06
# 33    33.23  0.05
# 35    35.56  0.20
# ..      ...   ...
# 233   10.09  0.37
# 249    8.98  0.32
# 250   10.73  0.47
# 265    8.52  0.50
# 269   11.23  0.14
# 270    9.34  0.21
# 278    9.41  0.70
# 285   14.14  0.39
# 286    7.81  0.64
# 287   10.73  0.17
# 294   12.32  0.63
# 312   10.29  0.56
# 322    5.82  0.16
# 323    6.77  0.76
# 332    8.92  0.29
# 333    7.42  0.66
# 341    4.97  0.90
# 349    6.45  0.49
# 361    9.01  0.31
# 378    6.46  0.44
# 381    4.90  0.67
# 390    5.38  0.44
# 403    3.50  0.53
# 405    4.27  0.46
# 407    6.17  0.61
# 413    2.53  0.38
# 431    7.09  0.82
# 435    3.55  0.30
# 444    3.39  0.33
# 451    3.72  0.74
#
# [119 rows x 2 columns]

# %%
plt.scatter(df.DIA,df.AMIN, color = 'red')

# %%
new_df = df.drop('AMIN',axis='columns')
new_df
AMIN.dropna()
# Out:
# 0      0.05
# 1      0.19
# 2      0.06
# 3      0.22
# 4      0.18
# 5      0.35
# 7      0.17
# 8      0.20
# 9      0.02
# 10     0.21
# 11     0.16
# 12     0.14
# 13     0.07
# 14     0.13
# 15     0.03
# 17     0.17
# 18     0.24
# 19     0.06
# 20     0.19
# 21     0.19
# 22     0.25
# 23     0.11
# 24     0.30
# 27     0.64
# 28     0.14
# 29     0.14
# 31     0.20
# 32     0.06
# 33     0.05
# 35     0.20
#        ...
# 233    0.37
# 249    0.32
# 250    0.47
# 265    0.50
# 269    0.14
# 270    0.21
# 278    0.70
# 285    0.39
# 286    0.64
# 287    0.17
# 294    0.63
# 312    0.56
# 322    0.16
# 323    0.76
# 332    0.29
# 333    0.66
# 341    0.90
# 349    0.49
# 361    0.31
# 378    0.44
# 381    0.67
# 390    0.44
# 403    0.53
# 405    0.46
# 407    0.61
# 413    0.38
# 431    0.82
# 435    0.30
# 444    0.33
# 451    0.74
# Name: AMIN, Length: 119, dtype: float64

# %%
AMIN = df.AMIN
AMIN
AMIN.dropna()
# Out:
# 0      0.05
# 1      0.19
# 2      0.06
# 3      0.22
# 4      0.18
# 5      0.35
# 7      0.17
# 8      0.20
# 9      0.02
# 10     0.21
# 11     0.16
# 12     0.14
# 13     0.07
# 14     0.13
# 15     0.03
# 17     0.17
# 18     0.24
# 19     0.06
# 20     0.19
# 21     0.19
# 22     0.25
# 23     0.11
# 24     0.30
# 27     0.64
# 28     0.14
# 29     0.14
# 31     0.20
# 32     0.06
# 33     0.05
# 35     0.20
#        ...
# 233    0.37
# 249    0.32
# 250    0.47
# 265    0.50
# 269    0.14
# 270    0.21
# 278    0.70
# 285    0.39
# 286    0.64
# 287    0.17
# 294    0.63
# 312    0.56
# 322    0.16
# 323    0.76
# 332    0.29
# 333    0.66
# 341    0.90
# 349    0.49
# 361    0.31
# 378    0.44
# 381    0.67
# 390    0.44
# 403    0.53
# 405    0.46
# 407    0.61
# 413    0.38
# 431    0.82
# 435    0.30
# 444    0.33
# 451    0.74
# Name: AMIN, Length: 119, dtype: float64

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)
clean_dataset(df)
# Out:
#      index     DIA  AMIN
# 0      0.0  103.87  0.05
# 1      1.0   24.57  0.19
# 2      2.0   38.25  0.06
# 3      3.0   33.46  0.22
# 4      4.0   50.15  0.18
# 5      5.0   28.61  0.35
# 7      7.0   30.56  0.17
# 8      8.0   48.21  0.20
# 9      9.0   85.95  0.02
# 10    10.0   39.78  0.21
# 11    11.0   25.39  0.16
# 12    12.0   34.37  0.14
# 13    13.0   70.80  0.07
# 14    14.0   33.04  0.13
# 15    15.0   39.18  0.03
# 17    17.0   31.75  0.17
# 18    18.0   45.60  0.24
# 19    19.0   31.18  0.06
# 20    20.0   33.54  0.19
# 21    21.0   43.01  0.19
# 22    22.0   26.15  0.25
# 23    23.0   21.40  0.11
# 24    24.0   27.33  0.30
# 27    27.0   35.52  0.64
# 28    28.0   31.67  0.14
# 29    29.0   31.53  0.14
# 31    31.0   35.76  0.20
# 32    32.0   34.80  0.06
# 33    33.0   33.23  0.05
# 35    35.0   35.56  0.20
# ..     ...     ...   ...
# 233  233.0   10.09  0.37
# 249  249.0    8.98  0.32
# 250  250.0   10.73  0.47
# 265  265.0    8.52  0.50
# 269  269.0   11.23  0.14
# 270  270.0    9.34  0.21
# 278  278.0    9.41  0.70
# 285  285.0   14.14  0.39
# 286  286.0    7.81  0.64
# 287  287.0   10.73  0.17
# 294  294.0   12.32  0.63
# 312  312.0   10.29  0.56
# 322  322.0    5.82  0.16
# 323  323.0    6.77  0.76
# 332  332.0    8.92  0.29
# 333  333.0    7.42  0.66
# 341  341.0    4.97  0.90
# 349  349.0    6.45  0.49
# 361  361.0    9.01  0.31
# 378  378.0    6.46  0.44
# 381  381.0    4.90  0.67
# 390  390.0    5.38  0.44
# 403  403.0    3.50  0.53
# 405  405.0    4.27  0.46
# 407  407.0    6.17  0.61
# 413  413.0    2.53  0.38
# 431  431.0    7.09  0.82
# 435  435.0    3.55  0.30
# 444  444.0    3.39  0.33
# 451  451.0    3.72  0.74
#
# [119 rows x 3 columns]

# %%
#new_df = new_df.reset_index()
#AMIN = AMIN.reset_index()
clean_dataset(new_df)
#clean_dataset(AMIN)
reg = linear_model.LinearRegression()
reg.fit(new_df,AMIN)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-6622e7ca95db> in <module>()
#       4 #clean_dataset(AMIN)
#       5 reg = linear_model.LinearRegression()
# ----> 6 reg.fit(new_df,AMIN)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
# --> 576                         dtype=None)
#     577     else:
#     578         y = column_or_1d(y, warn=True)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     451                              % (array.ndim, estimator_name))
#     452         if force_all_finite:
# --> 453             _assert_all_finite(array)
#     454
#     455     shape_repr = _shape_repr(array.shape)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X)
#      42             and not np.isfinite(X).all()):
#      43         raise ValueError("Input contains NaN, infinity"
# ---> 44                          " or a value too large for %r." % X.dtype)
#      45
#      46
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-da9a9ddd7447> in <module>()
# ----> 1 mat.sum()
#
# NameError: name 'mat' is not defined
